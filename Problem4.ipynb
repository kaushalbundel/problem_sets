# %% [markdown]
# # Problem
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %% [markdown]
# # Solution
#
# 1. Creating a function to check if a number is pallindrome our not
# 2. Reiterate the function over the product of all three digit numbers
# 3. Find out the maximum number that is a pallindrome

# %%
def is_pallindrome(number: int):
    num=str(number)
    if num[::-1] == num:
        return number
    else:
        return f"The number {number} is not a pallindrome"

# %%
is_pallindrome(1001), is_pallindrome(102)
# Out:
# (1001, 'The number 102 is not a pallindrome')

# %%
blank_list=[]
def prod_pallindrome(number1: int, number2: int):
    for num1 in range(100, number1):
        for num2 in range(100, number2):
            prod=num1 * num2
            prod1=str(prod)
            if prod1[::-1]==prod1:
                print(f"The product of {num1} and {num2} is {prod1}. This is a pallindrome")
                print("-------xxx--------")
                blank_list.append(prod)

# %%
prod_pallindrome(1000, 1000)
# Out:
# The product of 101 and 101 is 10201. This is a pallindrome
# -------xxx--------
# The product of 101 and 111 is 11211. This is a pallindrome
# -------xxx--------
# The product of 101 and 121 is 12221. This is a pallindrome
# -------xxx--------
# The product of 101 and 131 is 13231. This is a pallindrome
# -------xxx--------
# The product of 101 and 141 is 14241. This is a pallindrome
# -------xxx--------
# The product of 101 and 151 is 15251. This is a pallindrome
# -------xxx--------
# The product of 101 and 161 is 16261. This is a pallindrome
# -------xxx--------
# The product of 101 and 171 is 17271. This is a pallindrome
# -------xxx--------
# The product of 101 and 181 is 18281. This is a pallindrome
# -------xxx--------
# The product of 101 and 191 is 19291. This is a pallindrome
# -------xxx--------
# The product of 101 and 202 is 20402. This is a pallindrome
# -------xxx--------
# The product of 101 and 212 is 21412. This is a pallindrome
# -------xxx--------
# ...

# %%
max(blank_list)
# Out:
# 906609
